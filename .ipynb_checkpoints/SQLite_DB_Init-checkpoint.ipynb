# %%
# Good video to start from (some syntax is deprecated): https://www.youtube.com/watch?v=qUrtLJcehE0
# DDL (define) - Create, Alter, Drop          - Command: SQLite.DB()
# DML (manipulate) - Insert, Update, Delete   - Command: SQLite.execute(
# DQL (query) - Select                        - Command: SQLite.Query()


using SQLite
# Dataframes adds ability to visualize nicer
using DataFrames


# Creates or open a file named "test_database.sqlite" in the current directory
db = SQLite.DB("test_simple_grid_database.sqlite")
# Out:
# SQLite.DB("test_simple_grid_database.sqlite")

# %%
# Create all tables
# Primary key is created by default in SQLite, access it using ROWID

# Subscribers
SQLite.execute(db, "CREATE TABLE IF NOT EXISTS subscribers(
    account_id INTEGER PRIMARY KEY,
    name TEXT, 
    email TEXT)
    ")

# Buses
SQLite.execute(db, "CREATE TABLE IF NOT EXISTS buses(
    bus_key_id INTEGER PRIMARY KEY,
    bus_id INTEGER, 
    address TEXT,
    account_id INTEGER,
    FOREIGN KEY(account_id) REFERENCES subscribers(account_id))
    ")

# Records
SQLite.execute(db, "CREATE TABLE IF NOT EXISTS records(
    record_id INTEGER PRIMARY KEY,
    record_time DATETIME, 
    power_quality REAL,
    status INTEGER,
    bus_id INTEGER,
    FOREIGN KEY(bus_id) REFERENCES buses(bus_id))
    ")

# Global Records
SQLite.execute(db, "CREATE TABLE IF NOT EXISTS globalRecords(
    global_record_id INTEGER PRIMARY KEY,
    record_time DATETIME, 
    power_quality REAL,
    num_islands INTEGER,
    converges INTEGER)
    ")
# Out:
# 101

# %%
SQLite.execute(db, "DROP TABLE subscribers")
# Out:
# 101

# %%
SQLite.tables(db)
# Out:
# 5-element Vector{SQLite.DBTable}:
#  SQLite.DBTable("sqlite_sequence", Tables.Schema:
#  :name  Missing
#  :seq   Missing)
#  SQLite.DBTable("subscribers", Tables.Schema:
#  :account_id  Union{Missing, Int64}
#  :name        Union{Missing, String}
#  :email       Union{Missing, String})
#  SQLite.DBTable("buses", Tables.Schema:
#  :bus_key_id  Union{Missing, Int64}
#  :bus_id      Union{Missing, Int64}
#  :address     Union{Missing, String}
#  :account_id  Union{Missing, Int64})
#  SQLite.DBTable("records", Tables.Schema:
#  :record_id      Union{Missing, Int64}
#  :power_quality  Union{Missing, Float64}
#  :status         Union{Missing, Int64}
#  :bus_id         Union{Missing, Int64})
#  SQLite.DBTable("globalRecords", Tables.Schema:
#  :global_record_id  Union{Missing, Int64}
#  :record_time       Missing
#  :power_quality     Union{Missing, Float64}
#  :num_islands       Union{Missing, Int64}
#  :converges         Union{Missing, Int64})

# %%
# Populate subscribers and buses with generic data

# Name and Email pairings
subs = [
    ("Alice Vance", "alice@grid.org"),
    ("Bob Miller", "bob@outlook.com"),
    ("Charlie Day", "charlie@paddys.pub"),
    ("Diana Prince", "diana@gmail.com"),
    ("Edward Jones", "ed@riddle.co")
]

for s in subs
    SQLite.execute(db, "INSERT INTO subscribers (name, email) VALUES (?, ?)", [s[1], s[2]])
end

# Format: (bus_id, address, account_id)
buses = [
    (1, "Sector 7G Power Plant", 1),
    (2, "North Substation A", 1),
    (3, "Downtown Hub", 2),
    (4, "South Side Transformer", 3),
    (5, "West End Feeder", 3),
    (6, "Charlie's Home", 3),
    (7, "Amazonian Relay", 4),
    (8, "Question Mark Manor", 5)
]


for b in buses
    SQLite.execute(db, "INSERT INTO buses (bus_id, address, account_id) VALUES (?, ?, ?)", [b[1], b[2], b[3]])
end

# %%
# Print the buses

result = DBInterface.execute(db, "SELECT * FROM buses")

# Use dataFrame to visualize
df = DataFrame(result)
# Out:
# 8×4 DataFrame
#  Row │ bus_key_id  bus_id  address                 account_id
#      │ Int64       Int64   String                  Int64
# ─────┼────────────────────────────────────────────────────────
#    1 │          1     101  Sector 7G Power Plant            1
#    2 │          2     102  North Substation A               1
#    3 │          3     201  Downtown Hub                     2
#    4 │          4     301  South Side Transformer           3
#    5 │          5     302  West End Feeder                  3
#    6 │          6     303  Charlie's Backup Gen             3
#    7 │          7     401  Amazonian Relay                  4
#    8 │          8     501  Question Mark Manor              5

# %%
# Print the subscribers

result = DBInterface.execute(db, "SELECT * FROM subscribers")

# Use dataFrame to visualize
df = DataFrame(result)
# Out:
# SQLiteException("DB is closed")
#
# Stacktrace:
#   [1] sqliteexception
#     @ C:\Users\RedDv\.julia\packages\SQLite\0ctl8\src\SQLite.jl:23 [inlined]
#   [2] sqliteexception
#     @ C:\Users\RedDv\.julia\packages\SQLite\0ctl8\src\SQLite.jl:154 [inlined]
#   [3] sqliteerror(args::SQLite.DB)
#     @ SQLite C:\Users\RedDv\.julia\packages\SQLite\0ctl8\src\SQLite.jl:36
#   [4] macro expansion
#     @ C:\Users\RedDv\.julia\packages\SQLite\0ctl8\src\base.jl:10 [inlined]
#   [5] prepare_stmt_wrapper
#     @ C:\Users\RedDv\.julia\packages\SQLite\0ctl8\src\SQLite.jl:163 [inlined]
#   [6] SQLite.Stmt(db::SQLite.DB, sql::String; register::Bool)
#     @ SQLite C:\Users\RedDv\.julia\packages\SQLite\0ctl8\src\SQLite.jl:200
#   [7] Stmt
#     @ C:\Users\RedDv\.julia\packages\SQLite\0ctl8\src\SQLite.jl:199 [inlined]
#   [8] prepare
#     @ C:\Users\RedDv\.julia\packages\SQLite\0ctl8\src\SQLite.jl:234 [inlined]
#   [9] execute
#     @ C:\Users\RedDv\.julia\packages\DBInterface\nQcsk\src\DBInterface.jl:130 [inlined]
#  [10] execute(conn::SQLite.DB, sql::String)
#     @ DBInterface C:\Users\RedDv\.julia\packages\DBInterface\nQcsk\src\DBInterface.jl:152
#  [11] top-level scope
#     @ In[19]:3
#  [12] eval(m::Module, e::Any)
#     @ Core .\boot.jl:489

# %%
# Print the records

result = DBInterface.execute(db, "SELECT * FROM records")

# Use dataFrame to visualize
df = DataFrame(result)
# Out:
# 0×5 DataFrame
#  Row │ record_id  record_time  power_quality  status  bus_id
#      │ Int64?     Missing      Float64?       Int64?  Int64?
# ─────┴───────────────────────────────────────────────────────
